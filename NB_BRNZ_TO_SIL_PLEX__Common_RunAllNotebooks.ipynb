# %% [markdown]
# <img src="https://ac.auriasolutions.com/library/images/auria_logo_sm.jpg"/>

# %% [markdown]
# #### Update Schema

# %%
# %run NB_BRNZ_TO_SIL_PLEX__Common_UpdateSchema
# Out:
# StatementMeta(, 3532da21-31b8-4288-b31d-9fcb1b4382b5, 54, Finished, Available, Finished, True)
# 20260226194046
# <Spark SQL result set with 1 rows and 2 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %% [markdown]
# #### Run Silver Notebooks

# %%
# %run NB_BRNZ_TO_SIL_PLEX__Common_Functions
# Out:
# StatementMeta(, 3532da21-31b8-4288-b31d-9fcb1b4382b5, 55, Finished, Available, Finished, True)

# %%
debug_mode = False # Include debug select and print statements
# Out:
# StatementMeta(, 3532da21-31b8-4288-b31d-9fcb1b4382b5, 56, Finished, Available, Finished, False)

# %%
import uuid
from datetime import datetime
#Do not re-run this cell if you want to keep the current grouping
run_grouping_id = str(uuid.uuid4())
run_dttm = str(datetime.now())

if debug_mode:
    print("Current Run GroupingID is "+run_grouping_id)
params = {"run_grouping_id":run_grouping_id, "run_dttm":run_dttm}


notebook_timeout = 2400
max_concurrent_notebooks = 4
retries = 0

notebooks = [
	NotebookData("NB_BRNZ_TO_SIL_PLEX_commodity", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_line_item", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_period", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_po", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_receipt", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_supplier", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_AR_Inv_Details", notebook_timeout, params),	
	NotebookData("NB_BRNZ_TO_SIL_PLEX_customer_address", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_customer", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_currency", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_Approved_workcenter", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_Cost_sub_type", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_cost_type1", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_Customer_part", notebook_timeout, params),
	#NotebookData("NB_BRNZ_TO_SIL_PLEX_Exploded_BOM", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_location", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part_group", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part_master", notebook_timeout, params),	
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part_op_type", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part_operation", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part_product_type", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part_source", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part_status", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_part_type", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_po_line", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_price", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_workcenter", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_Cost_Model", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_part_BOM", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_multi_out", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_cost_component", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_operation", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_part_material", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_material_status", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_material", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_cost_BOM", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_item", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_plex_item_type", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_shipper", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_shipper_container", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_shipper_line", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_Customer_address", notebook_timeout, params),
	NotebookData("NB_BRNZ_TO_SIL_PLEX_Customer_part", notebook_timeout, params),
]   
    
res = parallelNotebooks(notebooks, max_concurrent_notebooks)
result = [i.result(timeout=notebook_timeout+120) for i in res] # This is a blocking call.
# Out:
# StatementMeta(, 3532da21-31b8-4288-b31d-9fcb1b4382b5, 57, Finished, Available, Finished, False)
# Running notebook NB_BRNZ_TO_SIL_PLEX_commodity
# Running notebook NB_BRNZ_TO_SIL_PLEX_line_item
# Running notebook NB_BRNZ_TO_SIL_PLEX_part
# Running notebook NB_BRNZ_TO_SIL_PLEX_period
# Finished notebook NB_BRNZ_TO_SIL_PLEX_commodity
# Running notebook NB_BRNZ_TO_SIL_PLEX_po
# Finished notebook NB_BRNZ_TO_SIL_PLEX_part
# Running notebook NB_BRNZ_TO_SIL_PLEX_receipt
# Finished notebook NB_BRNZ_TO_SIL_PLEX_period
# Running notebook NB_BRNZ_TO_SIL_PLEX_supplier
# Finished notebook NB_BRNZ_TO_SIL_PLEX_line_item
# Running notebook NB_BRNZ_TO_SIL_PLEX_AR_Inv_Details
# Finished notebook NB_BRNZ_TO_SIL_PLEX_receipt
# Running notebook NB_BRNZ_TO_SIL_PLEX_customer_address
# Finished notebook NB_BRNZ_TO_SIL_PLEX_supplier
# Running notebook NB_BRNZ_TO_SIL_PLEX_customer
# Finished notebook NB_BRNZ_TO_SIL_PLEX_po
# Running notebook NB_BRNZ_TO_SIL_PLEX_currency
# ...
