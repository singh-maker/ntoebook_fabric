# %% [markdown]
# ### Optimize Silver Tables

# %% [markdown]
# #### Process table commodity

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`commodity`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 2, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %% [markdown]
# #### Process table line_item

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`line_item`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 3, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %% [markdown]
# #### Process table part

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`part`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 4, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %% [markdown]
# #### Process table period

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`period`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 5, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %% [markdown]
# #### Process table po

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`po`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 6, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %% [markdown]
# #### Process table receipt

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`receipt`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 7, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %% [markdown]
# #### Process table supplier

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`supplier`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 8, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %% [markdown]
# #### Process table AR Inv Details

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`AR_Inv_Details`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 9, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`currency`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 10, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`customer`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 11, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`customer_address`
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 12, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 2 fields>

# %%
# %%sql
# OPTIMIZE LH_BI_SILVER_TIER1.`cost_model`

# %%
#Done.
# Out:
# StatementMeta(, 7751c545-9d23-4c98-b94e-81b0121eabbb, 14, Finished, Available, Finished)
